# %%
from paperbridge.clients import ZoteroClient
from dotenv import load_dotenv
load_dotenv()
import os

ZOTERO_API_KEY = os.getenv("ZOTERO_API_KEY")
ZOTERO_LIBRARY_ID = os.getenv("ZOTERO_LIBRARY_ID")
ZOTERO_GROUP_ID = os.getenv("ZOTERO_GROUP_ID")

# %%
with ZoteroClient(
    api_key=ZOTERO_API_KEY,
    library_id=ZOTERO_GROUP_ID,
    library_type="group",
) as zot:
    results = zot.get_items(limit=5)

# %%
with ZoteroClient(api_key=ZOTERO_API_KEY, library_id=ZOTERO_LIBRARY_ID) as zot:
    results = zot.get_items(limit=5)

# %%
results.items[0].data
# Out:
# ZoteroItemData(key='YIB7DB9V', version=621, item_type='attachment', title='Full Text PDF', creators=[], abstract_note=None, publication_title=None, volume=None, issue=None, pages=None, date=None, doi=None, issn=None, url='https://www.cell.com/cell/pdf/S0092-8674(25)01305-4.pdf', tags=[], collections=[], relations={}, date_added='2026-03-24T14:08:34Z', date_modified='2026-03-24T14:08:34Z', extra=None, parentItem='69ZM77XZ', linkMode='imported_url', accessDate='2026-03-24T14:08:34Z', note='', contentType='application/pdf', charset='', filename='Jiang et al. - 2026 - Psilocybin triggers an activity-dependent rewiring of large-scale cortical networks.pdf', md5='0b5e9cf3fa5d5ed90d2a1d25e0755f60', mtime=1774361314258)
